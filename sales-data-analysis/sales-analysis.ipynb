# %% [markdown]
# # Sales Data Analysis
#
# Analyze a sales dataset to uncover business insights and trends.

# %%
# Step 1: Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Step 2: Load data

# %%
df = pd.read_csv('sales.csv')
df.head()

# %% [markdown]
# ## Step 3: Data Cleaning

# %%
# Check for missing values
df.isnull().sum()

# %% [markdown]
# ## Step 4: Exploratory Data Analysis (EDA)

# %%
# Sales by product
df.groupby('Product')['Sales'].sum().plot(kind='bar')
plt.title('Total Sales by Product')
plt.ylabel('Sales')
plt.show()

# %%
# Sales over time
df['Date'] = pd.to_datetime(df['Date'])
df.groupby(df['Date'].dt.to_period('M'))['Sales'].sum().plot()
plt.title('Sales Over Time')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ## Step 5: Summary of Insights

# %%
# Example summary (edit as appropriate)
print('Product A is the top seller. Sales peaked in July. Consider stocking more Product A during summer months.')
